# %%
import pandas as pd

import datetime

import numpy as np

import matplotlib.pyplot as plt

from pandas.plotting import scatter_matrix

# !pip install yfinance

import yfinance as yf

# %matplotlib inline
# Out:
# Requirement already satisfied: yfinance in c:\users\mk9di\anaconda3\lib\site-packages (0.2.37)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\mk9di\anaconda3\lib\site-packages (from yfinance) (5.2.0)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\mk9di\anaconda3\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\mk9di\anaconda3\lib\site-packages (from yfinance) (1.20.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\mk9di\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\mk9di\anaconda3\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\mk9di\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: pytz>=2022.5 in c:\users\mk9di\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\mk9di\anaconda3\lib\site-packages (from yfinance) (1.3.4)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\mk9di\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: requests>=2.31 in c:\users\mk9di\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: html5lib>=1.1 in c:\users\mk9di\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mk9di\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.2.1)
# Requirement already satisfied: webencodings in c:\users\mk9di\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\mk9di\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mk9di\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mk9di\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mk9di\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mk9di\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mk9di\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)

# %%
start = "2022-01-01"
end = '2024-01-01'
apple = yf.download('AAPL',start,end)
amazon = yf.download('AMZN',start,end)
meta = yf.download('META',start,end)
mastercard = yf.download('MA',start,end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
apple['Volume'].plot(label = 'AAPL', figsize = (15,7))
amazon['Volume'].plot(label = "AMZN")
meta['Volume'].plot(label = 'META')
mastercard['Volume'].plot(label = 'MA')
plt.title('Volume of Stock traded')
plt.legend()

# %%
#Market Capitalisation
apple['MarktCap'] = apple['Open'] * apple['Volume']
amazon['MarktCap'] = amazon['Open'] * amazon['Volume']
meta['MarktCap'] = meta['Open'] * meta['Volume']
mastercard['MarktCap'] = mastercard['Open'] * mastercard['Volume']
apple['MarktCap'].plot(label = 'AAPL', figsize = (15,7))
amazon['MarktCap'].plot(label = 'AMZN')
meta['MarktCap'].plot(label = 'META')
mastercard['MarktCap'].plot(label = 'MA')
plt.title('Market Cap')
plt.legend()

# %%
#Moving Average
apple['MA50'] = apple['Open'].rolling(50).mean()
apple['MA200'] = apple['Open'].rolling(200).mean()
apple['Open'].plot(figsize = (15,7))
apple['MA50'].plot()
apple['MA200'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Volatility - percentage increase
apple['returns'] = (apple['Close']/apple['Close'].shift(1)) -1
amazon['returns'] = (amazon['Close']/amazon['Close'].shift(1))-1
meta['returns'] = (meta['Close']/meta['Close'].shift(1)) - 1
mastercard['returns'] = (mastercard['Close']/mastercard['Close'].shift(1)) - 1
apple['returns'].hist(bins = 100, label = 'Apple', alpha = 0.5, figsize = (15,7))
amazon['returns'].hist(bins = 100, label = 'Amazon', alpha = 0.5)
meta['returns'].hist(bins = 100, label = 'Meta', alpha = 0.5)
mastercard['returns'].hist(bins = 100, label = 'Mastercard', alpha = 0.5)
plt.legend()
